# %%
# Import Necessary Libraries:- 
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy
import statistics

# %%
# load DataSet:- 
df = pd.read_csv('user_behavior_dataset.csv')
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
# size of dataset:- 
df.size,df.shape
# Out:
# (7700, (700, 11))

# %%
df.groupby(['Device Model','Operating System'])['Battery Drain (mAh/day)'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                             mean  min   max         std  \
# Device Model       Operating System
# Google Pixel 5     Android           1475.676056  302  2968  809.354042
# OnePlus 9          Android           1523.849624  309  2956  835.151161
# Samsung Galaxy S21 Android           1504.571429  310  2920  820.700923
# Xiaomi Mi 11       Android           1528.876712  303  2993  821.442490
# iPhone 12          iOS               1589.513699  308  2971  817.175980
#
#                                                var  count     sum
# Device Model       Operating System
# Google Pixel 5     Android           655053.965238    142  209546
# OnePlus 9          Android           697477.462064    133  202672
# Samsung Galaxy S21 Android           673550.004329    133  200108
# Xiaomi Mi 11       Android           674767.764006    146  223216
# iPhone 12          iOS               667776.582570    146  232069

# %%
df.groupby(['Device Model','Operating System'])['Data Usage (MB/day)'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                            mean  min   max         std  \
# Device Model       Operating System
# Google Pixel 5     Android           897.704225  105  2481  643.885235
# OnePlus 9          Android           911.120301  103  2477  621.401337
# Samsung Galaxy S21 Android           931.872180  109  2481  645.794160
# Xiaomi Mi 11       Android           940.164384  102  2497  670.804828
# iPhone 12          iOS               965.506849  111  2416  624.746440
#
#                                                var  count     sum
# Device Model       Operating System
# Google Pixel 5     Android           414588.195585    142  127474
# OnePlus 9          Android           386139.621782    133  121179
# Samsung Galaxy S21 Android           417050.097175    133  123939
# Xiaomi Mi 11       Android           449979.117619    146  137264
# iPhone 12          iOS               390308.113746    146  140964

# %%
df.groupby(['Device Model','Operating System'])['User Behavior Class'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                          mean  min  max       std       var  \
# Device Model       Operating System
# Google Pixel 5     Android           2.915493    1    5  1.421681  2.021177
# OnePlus 9          Android           2.977444    1    5  1.405973  1.976760
# Samsung Galaxy S21 Android           2.977444    1    5  1.400574  1.961609
# Xiaomi Mi 11       Android           2.972603    1    5  1.423668  2.026830
# iPhone 12          iOS               3.102740    1    5  1.368258  1.872130
#
#                                      count  sum
# Device Model       Operating System
# Google Pixel 5     Android             142  414
# OnePlus 9          Android             133  396
# Samsung Galaxy S21 Android             133  396
# Xiaomi Mi 11       Android             146  434
# iPhone 12          iOS                 146  453

# %%
df.groupby(['Device Model','Operating System'])['Screen On Time (hours/day)'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                          mean  min   max       std       var  \
# Device Model       Operating System
# Google Pixel 5     Android           5.076056  1.1  11.8  3.097286  9.593182
# OnePlus 9          Android           5.241353  1.1  12.0  3.084569  9.514565
# Samsung Galaxy S21 Android           5.318045  1.0  11.8  3.079424  9.482854
# Xiaomi Mi 11       Android           5.293151  1.1  11.9  3.148084  9.910436
# iPhone 12          iOS               5.430822  1.0  11.9  2.965330  8.793181
#
#                                      count    sum
# Device Model       Operating System
# Google Pixel 5     Android             142  720.8
# OnePlus 9          Android             133  697.1
# Samsung Galaxy S21 Android             133  707.3
# Xiaomi Mi 11       Android             146  772.8
# iPhone 12          iOS                 146  792.9

# %%
df.groupby(['Device Model','Operating System'])['App Usage Time (min/day)'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                            mean  min  max         std  \
# Device Model       Operating System
# Google Pixel 5     Android           267.788732   34  595  180.031314
# OnePlus 9          Android           270.383459   30  598  183.494064
# Samsung Galaxy S21 Android           266.421053   30  593  175.264571
# Xiaomi Mi 11       Android           268.452055   31  597  179.765905
# iPhone 12          iOS               282.020548   32  597  169.592390
#
#                                               var  count    sum
# Device Model       Operating System
# Google Pixel 5     Android           32411.274198    142  38026
# OnePlus 9          Android           33670.071542    133  35961
# Samsung Galaxy S21 Android           30717.669856    133  35434
# Xiaomi Mi 11       Android           32315.780444    146  39194
# iPhone 12          iOS               28761.578885    146  41175

# %%
df.groupby(['Device Model','Operating System'])['Battery Drain (mAh/day)'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                             mean  min   max         std  \
# Device Model       Operating System
# Google Pixel 5     Android           1475.676056  302  2968  809.354042
# OnePlus 9          Android           1523.849624  309  2956  835.151161
# Samsung Galaxy S21 Android           1504.571429  310  2920  820.700923
# Xiaomi Mi 11       Android           1528.876712  303  2993  821.442490
# iPhone 12          iOS               1589.513699  308  2971  817.175980
#
#                                                var  count     sum
# Device Model       Operating System
# Google Pixel 5     Android           655053.965238    142  209546
# OnePlus 9          Android           697477.462064    133  202672
# Samsung Galaxy S21 Android           673550.004329    133  200108
# Xiaomi Mi 11       Android           674767.764006    146  223216
# iPhone 12          iOS               667776.582570    146  232069

# %%
df.columns
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')

# %%
df.melt(id_vars=['Device Model','Operating System'],value_vars=['Age','Gender','User Behavior Class'],var_name='Categories',value_name='Final Output').iloc[100:120]
# Out:
#            Device Model Operating System Categories Final Output
# 100      Google Pixel 5          Android        Age           53
# 101           OnePlus 9          Android        Age           19
# 102      Google Pixel 5          Android        Age           32
# 103        Xiaomi Mi 11          Android        Age           28
# 104        Xiaomi Mi 11          Android        Age           25
# 105        Xiaomi Mi 11          Android        Age           36
# 106      Google Pixel 5          Android        Age           55
# 107      Google Pixel 5          Android        Age           23
# 108        Xiaomi Mi 11          Android        Age           50
# 109           OnePlus 9          Android        Age           39
# 110           OnePlus 9          Android        Age           41
# 111        Xiaomi Mi 11          Android        Age           19
# 112      Google Pixel 5          Android        Age           27
# ...

# %%
df[df['Age'].isin([18,19])].pivot_table(index=['Age','Device Model','Gender'], values='App Usage Time (min/day)', aggfunc='mean')
# Male is lawarish...............
# Out:
#                                App Usage Time (min/day)
# Age Device Model       Gender
# 18  Google Pixel 5     Male                  287.333333
#     Samsung Galaxy S21 Male                  309.000000
#     Xiaomi Mi 11       Male                  244.666667
#     iPhone 12          Male                   75.000000
# 19  Google Pixel 5     Male                  314.000000
#     OnePlus 9          Female                425.000000
#                        Male                  131.500000
#     Samsung Galaxy S21 Female                412.000000
#     Xiaomi Mi 11       Female                154.500000
#                        Male                  263.500000
#     iPhone 12          Female                244.333333

# %%
df.pivot_table(index=['Device Model', 'Operating System','Gender'], values='App Usage Time (min/day)', aggfunc='mean')
# Out:
#                                             App Usage Time (min/day)
# Device Model       Operating System Gender
# Google Pixel 5     Android          Female                252.695652
#                                     Male                  282.054795
# OnePlus 9          Android          Female                265.918033
#                                     Male                  274.166667
# Samsung Galaxy S21 Android          Female                290.074074
#                                     Male                  250.253165
# Xiaomi Mi 11       Android          Female                267.974359
#                                     Male                  269.000000
# iPhone 12          iOS              Female                285.918919
#                                     Male                  278.013889

# %%
pd.to_datetime(df['App Usage Time (min/day)'])
# Out:
# 0     1970-01-01 00:00:00.000000393
# 1     1970-01-01 00:00:00.000000268
# 2     1970-01-01 00:00:00.000000154
# 3     1970-01-01 00:00:00.000000239
# 4     1970-01-01 00:00:00.000000187
#                    ...
# 695   1970-01-01 00:00:00.000000092
# 696   1970-01-01 00:00:00.000000316
# 697   1970-01-01 00:00:00.000000099
# 698   1970-01-01 00:00:00.000000062
# 699   1970-01-01 00:00:00.000000212
# Name: App Usage Time (min/day), Length: 700, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                700 non-null    object
#  2   Operating System            700 non-null    object
#  3   App Usage Time (min/day)    700 non-null    int64
#  4   Screen On Time (hours/day)  700 non-null    float64
#  5   Battery Drain (mAh/day)     700 non-null    int64
#  6   Number of Apps Installed    700 non-null    int64
#  7   Data Usage (MB/day)         700 non-null    int64
#  8   Age                         700 non-null    int64
#  9   Gender                      700 non-null    object
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 60.3+ KB

# %%
df.describe()
# Out:
#          User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.00000                700.000000                  700.000000
# mean   350.50000                271.128571                    5.272714
# std    202.21688                177.199484                    3.068584
# min      1.00000                 30.000000                    1.000000
# 25%    175.75000                113.250000                    2.500000
# 50%    350.50000                227.500000                    4.900000
# 75%    525.25000                434.250000                    7.400000
# max    700.00000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# ...

# %%
list(df['Device Model'].unique())
# Out:
# ['Google Pixel 5',
#  'OnePlus 9',
#  'Xiaomi Mi 11',
#  'iPhone 12',
#  'Samsung Galaxy S21']

# %%
df['Device Model'].value_counts()
# Out:
# Device Model
# Xiaomi Mi 11          146
# iPhone 12             146
# Google Pixel 5        142
# OnePlus 9             133
# Samsung Galaxy S21    133
# Name: count, dtype: int64

# %%
df['Device Model'].value_counts()['OnePlus 9']/len(df)
# Out:
# np.float64(0.19)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences of each model :-
model_counts = df['Device Model'].value_counts()

# Define colors for the pie chart :-
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']

# Create pie chart :-
plt.figure(figsize=(8, 8))
plt.pie(
    model_counts, 
    labels=model_counts.index, 
    colors=colors, 
    autopct='%1.1f%%',        # Show percentage on each slice
    startangle=140,           # Start angle for first slice
    wedgeprops={'edgecolor': 'black', 'linewidth': 1.5},  # Edge color and width
    shadow=True,              # Add shadow for a 3D effect
    explode=(0.1, 0, 0, 0, 0.1)  # Emphasize certain slices
)

# Add title
plt.title('Smartphone Model Distribution')

# Display the chart
plt.show()

# %%
sns.countplot(x='Device Model',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Device Model', ylabel='count'>

# %%
sns.countplot(x='Operating System',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Operating System', ylabel='count'>

# %%
sns.countplot(x='Gender',data =df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.distplot(df['App Usage Time (min/day)'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\3247403564.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['App Usage Time (min/day)'])
# <Axes: xlabel='App Usage Time (min/day)', ylabel='Density'>

# %%
sns.boxplot(df['App Usage Time (min/day)'])
# Out:
# <Axes: ylabel='App Usage Time (min/day)'>

# %%
sns.distplot(df['Screen On Time (hours/day)'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\110921487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Screen On Time (hours/day)'])
# <Axes: xlabel='Screen On Time (hours/day)', ylabel='Density'>

# %%
sns.distplot(df['Battery Drain (mAh/day)'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\779387186.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Battery Drain (mAh/day)'])
# <Axes: xlabel='Battery Drain (mAh/day)', ylabel='Density'>

# %%
sns.distplot(df['Number of Apps Installed'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\1847445485.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Number of Apps Installed'])
# <Axes: xlabel='Number of Apps Installed', ylabel='Density'>

# %%
sns.distplot(df['Data Usage (MB/day)'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\2787498504.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Data Usage (MB/day)'])
# <Axes: xlabel='Data Usage (MB/day)', ylabel='Density'>

# %%
sns.boxplot(df['Data Usage (MB/day)'])
# Out:
# <Axes: ylabel='Data Usage (MB/day)'>

# %%
print('Mean:-',df['User Behavior Class'].mean())
print('Mode:-',df['User Behavior Class'].mode())
print('Median:-',df['User Behavior Class'].median())
# Out:
# Mean:- 2.99
# Mode:- 0    2
# Name: User Behavior Class, dtype: int64
# Median:- 3.0

# %%
sns.distplot(df['User Behavior Class'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\2407837042.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['User Behavior Class'])
# <Axes: xlabel='User Behavior Class', ylabel='Density'>

# %%
sns.lineplot(x='Device Model',y='User Behavior Class',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='User Behavior Class'>

# %%
df.describe()
# Out:
#          User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.00000                700.000000                  700.000000
# mean   350.50000                271.128571                    5.272714
# std    202.21688                177.199484                    3.068584
# min      1.00000                 30.000000                    1.000000
# 25%    175.75000                113.250000                    2.500000
# 50%    350.50000                227.500000                    4.900000
# 75%    525.25000                434.250000                    7.400000
# max    700.00000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# ...

# %%
sns.barplot(x='Device Model',y='App Usage Time (min/day)',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='App Usage Time (min/day)'>

# %%
sns.barplot(x='Device Model',y='App Usage Time (min/day)',hue='Operating System',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='App Usage Time (min/day)'>

# %%
sns.barplot(x='Device Model',y='Screen On Time (hours/day)',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Screen On Time (hours/day)'>

# %%
sns.barplot(x='Device Model',y='Screen On Time (hours/day)',hue='Operating System',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Screen On Time (hours/day)'>

# %%
sns.barplot(x='Device Model',y='Battery Drain (mAh/day)',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Battery Drain (mAh/day)'>

# %%
sns.barplot(x='Device Model',y='Battery Drain (mAh/day)',hue='Operating System',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Battery Drain (mAh/day)'>

# %%
sns.barplot(x='Device Model',y='Number of Apps Installed',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Number of Apps Installed'>

# %%
sns.barplot(x='Device Model',y='Number of Apps Installed',hue='Operating System',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Number of Apps Installed'>

# %%
df[df['Device Model']=='Google Pixel 5']['Number of Apps Installed'].max()
# Out:
# np.int64(99)

# %%
sns.barplot(x='Device Model',y='Age',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Age'>

# %%
sns.barplot(x='Device Model',y='Data Usage (MB/day)',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Data Usage (MB/day)'>

# %%
sns.barplot(x='Device Model',y='Data Usage (MB/day)',hue='Operating System',data = df)
# Out:
# <Axes: xlabel='Device Model', ylabel='Data Usage (MB/day)'>

# %%
plt.hist('User Behavior Class',data=df)
# Out:
# (array([136.,   0., 146.,   0.,   0., 143.,   0., 139.,   0., 136.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
df.columns
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
df[df['Age']==18]
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 43        44  Samsung Galaxy S21          Android                       152
# 116      117           iPhone 12              iOS                        75
# 138      139  Samsung Galaxy S21          Android                       497
# 211      212  Samsung Galaxy S21          Android                       481
# 258      259        Xiaomi Mi 11          Android                       201
# 439      440      Google Pixel 5          Android                       123
# 561      562        Xiaomi Mi 11          Android                       121
# 569      570      Google Pixel 5          Android                       404
# 614      615  Samsung Galaxy S21          Android                       106
# 685      686        Xiaomi Mi 11          Android                       412
# 686      687      Google Pixel 5          Android                       335
#
# ...

# %%
male_df =df[df['Gender']=='Male']
female_df=df[df['Gender']=='Female']
male_df
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 5          6      Google Pixel 5          Android                        99
# 7          8           OnePlus 9          Android                       543
# ..       ...                 ...              ...                       ...
# 690      691      Google Pixel 5          Android                       195
# 693      694        Xiaomi Mi 11          Android                       505
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 698      699  Samsung Galaxy S21          Android                        62
#
# ...

# %%
male_df.describe()
# Out:
#           User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  364.000000                364.000000                  364.000000
# mean   354.239011                270.354396                    5.283242
# std    203.823873                180.130832                    3.152046
# min      1.000000                 30.000000                    1.000000
# 25%    175.750000                104.750000                    2.400000
# 50%    363.000000                222.000000                    4.800000
# 75%    522.500000                445.500000                    7.500000
# max    699.000000                595.000000                   11.900000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               364.000000                364.000000           364.000000
# mean               1530.090659                 51.101648           943.978022
# std                 843.420783                 27.496218           656.901886
# ...

# %%
female_df.describe()
# Out:
#           User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  336.000000                336.000000                  336.000000
# mean   346.449405                271.967262                    5.261310
# std    200.686428                174.232669                    2.980182
# min      2.000000                 31.000000                    1.000000
# 25%    175.750000                118.250000                    2.775000
# 50%    339.000000                230.000000                    4.900000
# 75%    527.250000                423.500000                    7.225000
# max    700.000000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               336.000000                336.000000           336.000000
# mean               1519.815476                 50.226190           914.321429
# std                 793.210963                 26.364653           622.750886
# ...

# %%
male_df.isnull().sum()
# Out:
# User ID                       0
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences of each model
model_counts = male_df['Device Model'].value_counts()

# Define colors for the pie chart
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    model_counts, 
    labels=model_counts.index, 
    colors=colors, 
    autopct='%1.1f%%',        # Show percentage on each slice
    startangle=140,           # Start angle for first slice
    wedgeprops={'edgecolor': 'black', 'linewidth': 1.5},  # Edge color and width
    shadow=True,              # Add shadow for a 3D effect
    explode=(0.1, 0, 0, 0, 0.1)  # Emphasize certain slices
)

# Add title
plt.title('Smartphone Model Distribution')

# Display the chart
plt.show()

# %%
male_df['Device Model'].value_counts()
# Out:
# Device Model
# Samsung Galaxy S21    79
# Google Pixel 5        73
# OnePlus 9             72
# iPhone 12             72
# Xiaomi Mi 11          68
# Name: count, dtype: int64

# %%
male_df['Device Model'].value_counts()['OnePlus 9']/len(male_df)
# Out:
# np.float64(0.1978021978021978)

# %%
male_df[male_df['Age']==18].pivot_table(index=['Age','Device Model','Operating System'], values='App Usage Time (min/day)', aggfunc='mean')
# Out:
#                                          App Usage Time (min/day)
# Age Device Model       Operating System
# 18  Google Pixel 5     Android                         287.333333
#     Samsung Galaxy S21 Android                         309.000000
#     Xiaomi Mi 11       Android                         244.666667
#     iPhone 12          iOS                              75.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences of each model
model_counts = female_df['Device Model'].value_counts()

# Define colors for the pie chart
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    model_counts, 
    labels=model_counts.index, 
    colors=colors, 
    autopct='%1.1f%%',        # Show percentage on each slice
    startangle=140,           # Start angle for first slice
    wedgeprops={'edgecolor': 'black', 'linewidth': 1.5},  # Edge color and width
    shadow=True,              # Add shadow for a 3D effect
    explode=(0.1, 0, 0, 0, 0.1)  # Emphasize certain slices
)

# Add title
plt.title('Smartphone Model Distribution')

# Display the chart
plt.show()

# %%
female_df['Device Model'].value_counts()['OnePlus 9']/len(female_df)
# Out:
# np.float64(0.18154761904761904)

# %%
female_df[female_df['Age']==19].pivot_table(index=['Age','Device Model','Operating System'], values='App Usage Time (min/day)', aggfunc='mean')
# Out:
#                                          App Usage Time (min/day)
# Age Device Model       Operating System
# 19  OnePlus 9          Android                         425.000000
#     Samsung Galaxy S21 Android                         412.000000
#     Xiaomi Mi 11       Android                         154.500000
#     iPhone 12          iOS                             244.333333

# %%
female_df['Device Model'].value_counts()
# Out:
# Device Model
# Xiaomi Mi 11          78
# iPhone 12             74
# Google Pixel 5        69
# OnePlus 9             61
# Samsung Galaxy S21    54
# Name: count, dtype: int64

# %%
male_df.drop('User ID',inplace=True,axis=1)
#df.drop(['CC Number','Payment ID','Payer Name'],axis=1,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\2282633727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_df.drop('User ID',inplace=True,axis=1)

# %%
male_df.columns
# Out:
# Index(['Device Model', 'Operating System', 'App Usage Time (min/day)',
#        'Screen On Time (hours/day)', 'Battery Drain (mAh/day)',
#        'Number of Apps Installed', 'Data Usage (MB/day)', 'Age', 'Gender',
#        'User Behavior Class'],
#       dtype='object')

# %%
plt.figure(figsize=(30,10))
sns.boxplot(male_df)
# Out:
# <Axes: >

# %%
female_df.drop('User ID',inplace=True,axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18372\1721138728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df.drop('User ID',inplace=True,axis=1)

# %%
plt.figure(figsize=(30,10))
sns.boxplot(female_df)
# Out:
# <Axes: >
