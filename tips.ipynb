# %%
# Load Necessaray Libraries:- 

import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy import stats
# %matplotlib inline

# %%
# Set the style for better-looking plots
#sns.set_palette("husl")

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns # dataset columns name:-
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
# Sahpe and size of database:- 
df.shape,  df.size
# Out:
# ((244, 11), 2684)

# %%
# Checke Null present in Dataset:- 
df.isnull().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# total_bill          0.0
# tip                 0.0
# sex                 0.0
# smoker              0.0
# day                 0.0
# time                0.0
# size                0.0
# price_per_person    0.0
# Payer Name          0.0
# CC Number           0.0
# Payment ID          0.0
# dtype: float64

# %%
# Check unique value for each columns:- 
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
plt.hist(df['day'])
# Out:
# (array([76.,  0.,  0., 87.,  0.,  0., 62.,  0.,  0., 19.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
plt.hist(df['size'])
# Out:
# (array([  4.,   0., 156.,   0.,  38.,   0.,  37.,   0.,   5.,   4.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
df['Payer Name'].nunique() , len(df['Payer Name'].unique())
# Out:
# (244, 244)

# %%
df.groupby('sex')['total_bill'].agg(['mean','std','var','min','max'])
# Out:
#           mean       std        var   min    max
# sex
# 0    18.056897  8.009209  64.147429  3.07  44.30
# 1    20.744076  9.246469  85.497185  7.25  50.81

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
# total Bills:- 
df['total_bill'].count()
# Out:
# np.int64(244)

# %%
print('Mean of Total bill :-',df['total_bill'].mean())
print('Variance of :- ',df['total_bill'].var())
print('Standard deviation of :- ',np.sqrt(df['total_bill'].var()))
# Out:
# Mean of Total bill :- 19.78594262295082
# Variance of :-  79.25293861397827
# Standard deviation of :-  8.902411954856856

# %%
sns.distplot(x=df['price_per_person'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13272\1985113661.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['price_per_person'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=df['size'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13272\1999573124.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['size'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=df['tip'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13272\550350232.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['tip'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(df['total_bill'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13272\1285936593.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
print('Miminum value of total bill :-',df['total_bill'].min())

print('Percentaile of total bill :-',df['total_bill'].quantile([0.25, 0.5, 0.75]))

print('Maxmium value of total bill :-',df['total_bill'].max())

print('Median value of total bill :-',df['total_bill'].median())

print('Mode value of total bill :-',df['total_bill'].mode())
# Out:
# Miminum value of total bill :- 3.07
# Percentaile of total bill :- 0.25    13.3475
# 0.50    17.7950
# 0.75    24.1275
# Name: total_bill, dtype: float64
# Maxmium value of total bill :- 50.81
# Median value of total bill :- 17.795
# Mode value of total bill :- 0    13.42
# Name: total_bill, dtype: float64

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
# Calculate a single percentile
print(np.percentile(df['total_bill'], 75))  # 75th percentile

# Calculate multiple percentiles
np.percentile(df['total_bill'], [25, 50, 75])  # Returns 25th, 50th (median), and 75th percentiles

# With additional parameters
np.percentile(df['total_bill'], 75, interpolation='nearest')  # Options: 'linear', 'lower', 'higher', 'midpoint', 'nearest'
# Out:
# 24.127499999999998
# np.float64(24.08)

# %%
# VaALUE  Count in each columns:- 
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.countplot(data=df['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.countplot(data=df['smoker'])
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
data = sns.countplot(df['day'])
for i in data.containers:
    print(data.bar_label(i))
# Out:
# [Text(0, 0, '76'), Text(0, 0, '87'), Text(0, 0, '62'), Text(0, 0, '19')]

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.countplot(data=df['time'])
# Out:
# <Axes: xlabel='count', ylabel='time'>

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.countplot(df['size'])
# Out:
# <Axes: ylabel='count'>

# %%
# Drop Unnecessary Columns:-
df.drop(['CC Number','Payment ID','Payer Name'],axis=1,inplace=True)

# %%
# Visulazation side:- 
sns.pairplot(data = df,hue='sex')

# %%
sns.pairplot(data = df,hue='smoker')

# %%
sns.pairplot(data = df,hue='day')

# %%
sns.pairplot(data = df,hue='time')

# %%
df['sex'] = pd.Categorical(df['sex']).codes
df['smoker'] = pd.Categorical(df['smoker']).codes
df['day'] = pd.Categorical(df['day']).codes
df['time'] = pd.Categorical(df['time']).codes

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size  price_per_person
# 0         16.99  1.01    0       0    2     0     2              8.49
# 1         10.34  1.66    1       0    2     0     3              3.45
# 2         21.01  3.50    1       0    2     0     3              7.00
# 3         23.68  3.31    1       0    2     0     2             11.84
# 4         24.59  3.61    0       0    2     0     4              6.15
# ..          ...   ...  ...     ...  ...   ...   ...               ...
# 239       29.03  5.92    1       0    1     0     3              9.68
# 240       27.18  2.00    0       1    1     0     2             13.59
# 241       22.67  2.00    1       1    1     0     2             11.34
# 242       17.82  1.75    1       0    1     0     2              8.91
# 243       18.78  3.00    0       0    3     0     2              9.39
#
# [244 rows x 8 columns]

# %%
pd.pivot_table(df,index='sex',columns='time')
# Out:
#            day           price_per_person                size            \
# time         0         1                0         1         0         1
# sex
# 0     1.288462  2.657143         7.910962  6.800857  2.461538  2.457143
# 1     1.411290  2.727273         8.192339  7.862727  2.701613  2.363636
#
#         smoker                 tip           total_bill
# time         0         1         0         1          0          1
# sex
# 0     0.442308  0.285714  3.002115  2.582857  19.213077  16.339143
# 1     0.379032  0.393939  3.144839  2.882121  21.461452  18.048485

# %%
pd.pivot_table(df,index='sex',columns='time',values=['price_per_person','tip'])
# Out:
#      price_per_person                 tip
# time                0         1         0         1
# sex
# 0            7.910962  6.800857  3.002115  2.582857
# 1            8.192339  7.862727  3.144839  2.882121

# %%
plt.figure(figsize=(10, 8))
# numerical_cols = df.select_dtypes(include=[np.number]).columns
# orrelation = df[numerical_cols].corr()
correlation = df.corr()

sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0,
            square=True, fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap', pad=20)
plt.tight_layout()
#plt.gcf()

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person'],
#       dtype='object')

# %%
sns.lineplot(x='size',y='tip',data = df)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.lineplot(x='day',y='tip',data = df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.lineplot(x='time',y='tip',data = df)
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.lineplot(x='sex',y='tip',data = df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.histplot(df['total_bill'],kde=True,color='blue')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df['total_bill'].mean(),df['total_bill'].median(),df['total_bill'].mode() # right skew meann positive
# Out:
# (np.float64(19.78594262295082),
#  np.float64(17.795),
#  0    13.42
#  Name: total_bill, dtype: float64)

# %%
sns.histplot(df['day'],kde=True)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.histplot(df['price_per_person'],kde=True,color='green')
# Out:
# <Axes: xlabel='price_per_person', ylabel='Count'>

# %%
df['price_per_person'].mean(),df['price_per_person'].median(),df['price_per_person'].mode()
# Out:
# (np.float64(7.888196721311474),
#  np.float64(7.255),
#  0     6.71
#  1    10.14
#  Name: price_per_person, dtype: float64)

# %%
sns.histplot(df['tip'],kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df['tip'].mean(),df['tip'].median(),df['tip'].mode()
# Out:
# (np.float64(2.99827868852459),
#  np.float64(2.9),
#  0    2.0
#  Name: tip, dtype: float64)

# %%
sns.barplot(x='tip',y='total_bill',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size  price_per_person
# 0         16.99  1.01    0       0    2     0     2              8.49
# 1         10.34  1.66    1       0    2     0     3              3.45
# 2         21.01  3.50    1       0    2     0     3              7.00
# 3         23.68  3.31    1       0    2     0     2             11.84
# 4         24.59  3.61    0       0    2     0     4              6.15
# ..          ...   ...  ...     ...  ...   ...   ...               ...
# 239       29.03  5.92    1       0    1     0     3              9.68
# 240       27.18  2.00    0       1    1     0     2             13.59
# 241       22.67  2.00    1       1    1     0     2             11.34
# 242       17.82  1.75    1       0    1     0     2              8.91
# 243       18.78  3.00    0       0    3     0     2              9.39
#
# [244 rows x 8 columns]

# %%
sns.barplot(x='price_per_person',y='tip',hue='smoker',data=df) # hue ='sex' 'smoker',time
# Out:
# <Axes: xlabel='price_per_person', ylabel='tip'>

# %%
sns.barplot(x='day',y='tip',hue='time',data=df) # hue ='sex' 'smoker',time
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='size',y='tip',hue='smoker',data=df) # hue ='sex' 'smoker',time
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.barplot(x='size',y='total_bill',hue='smoker',data=df) # hue ='sex' 'smoker',time
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='price_per_person',y='total_bill',hue='time',data=df) # hue ='sex' 'smoker',time
# Out:
# <Axes: xlabel='price_per_person', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='smoker',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='time',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df.groupby('day')['total_bill'].agg(['mean','max','min','count','sum'])
# Out:
#           mean    max   min  count      sum
# day
# 0    17.151579  40.17  5.75     19   325.88
# 1    20.441379  50.81  3.07     87  1778.40
# 2    21.410000  48.17  7.25     76  1627.16
# 3    17.682742  43.11  7.51     62  1096.33

# %%
''' 
This project concerns tips and total bill amounts based on customer gender, 
time, working days, whether customers smoke, and the per-person price.
'''
