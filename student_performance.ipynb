# %%
# Import Necessary Libraries:- 
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy
import statistics

# %%
# Load the Data Set:- 
df = pd.read_csv('StudentPerformanceFactors.csv')
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.head().T
# Out:
#                                       0         1             2            3  \
# Hours_Studied                        23        19            24           29
# Attendance                           84        64            98           89
# Parental_Involvement                Low       Low        Medium          Low
# Access_to_Resources                High    Medium        Medium       Medium
# Extracurricular_Activities           No        No           Yes          Yes
# Sleep_Hours                           7         8             7            8
# Previous_Scores                      73        59            91           98
# Motivation_Level                    Low       Low        Medium       Medium
# Internet_Access                     Yes       Yes           Yes          Yes
# Tutoring_Sessions                     0         2             2            1
# Family_Income                       Low    Medium        Medium       Medium
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.size,df.shape
# Out:
# (132140, (6607, 20))

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
round(df.isnull().sum()/df.shape[0] * 100,2)
# Out:
# Hours_Studied                 0.00
# Attendance                    0.00
# Parental_Involvement          0.00
# Access_to_Resources           0.00
# Extracurricular_Activities    0.00
# Sleep_Hours                   0.00
# Previous_Scores               0.00
# Motivation_Level              0.00
# Internet_Access               0.00
# Tutoring_Sessions             0.00
# Family_Income                 0.00
# Teacher_Quality               1.18
# School_Type                   0.00
# Peer_Influence                0.00
# Physical_Activity             0.00
# Learning_Disabilities         0.00
# Parental_Education_Level      1.36
# Distance_from_Home            1.01
# Gender                        0.00
# Exam_Score                    0.00
# dtype: float64

# %%
(df.isnull().sum().sum() / (df.shape[0] * df.shape[1])) * 100
# Out:
# np.float64(0.1778416830634176)

# %%
df.notnull().sum().sum()
# Out:
# 131905

# %%
df.isnull().sum().sum()
# Out:
# np.int64(235)

# %%
df.notnull().sum().sum() + df.isnull().sum().sum()
# Out:
# np.int64(132140)

# %%
df.shape,df.size
# Out:
# ((6607, 20), 132140)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df.notnull())
# Out:
# <Axes: >

# %%
df.head().T
# Out:
#                                       0         1             2            3  \
# Hours_Studied                        23        19            24           29
# Attendance                           84        64            98           89
# Parental_Involvement                Low       Low        Medium          Low
# Access_to_Resources                High    Medium        Medium       Medium
# Extracurricular_Activities           No        No           Yes          Yes
# Sleep_Hours                           7         8             7            8
# Previous_Scores                      73        59            91           98
# Motivation_Level                    Low       Low        Medium       Medium
# Internet_Access                     Yes       Yes           Yes          Yes
# Tutoring_Sessions                     0         2             2            1
# Family_Income                       Low    Medium        Medium       Medium
# ...

# %%
df['Peer_Influence'].value_counts()
# Out:
# Peer_Influence
# Positive    2638
# Neutral     2592
# Negative    1377
# Name: count, dtype: int64

# %%
sns.countplot(x='Peer_Influence',hue='Gender',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Peer_Influence', ylabel='count'>

# %%
sns.countplot(x='Peer_Influence',hue='Learning_Disabilities',data = df)
# Out:
# <Axes: xlabel='Peer_Influence', ylabel='count'>

# %%
sns.countplot(x='Peer_Influence',hue='Internet_Access',data = df)
# Out:
# <Axes: xlabel='Peer_Influence', ylabel='count'>

# %%
sns.countplot(x='Peer_Influence',hue='Extracurricular_Activities',data = df)
# Out:
# <Axes: xlabel='Peer_Influence', ylabel='count'>

# %%
sns.countplot(x='Peer_Influence',hue='School_Type',data = df)
# Out:
# <Axes: xlabel='Peer_Influence', ylabel='count'>

# %%
plt.bar(df['Gender'],df['Peer_Influence']) # hist
plt.show()

# %%
df['Learning_Disabilities'].value_counts()
# Out:
# Learning_Disabilities
# No     5912
# Yes     695
# Name: count, dtype: int64

# %%
df['Parental_Education_Level'].value_counts()
# Out:
# Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# Name: count, dtype: int64

# %%
sns.countplot(x='Parental_Education_Level',hue='Gender',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='count'>

# %%
sns.countplot(x='Parental_Education_Level',hue='Learning_Disabilities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='count'>

# %%
sns.countplot(x='Parental_Education_Level',hue='Internet_Access',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='count'>

# %%
sns.countplot(x='Parental_Education_Level',hue='Extracurricular_Activities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='count'>

# %%
sns.countplot(x='Parental_Education_Level',hue='School_Type',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='count'>

# %%
sns.countplot(x='Distance_from_Home',hue='Gender',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Distance_from_Home', ylabel='count'>

# %%
sns.countplot(x='Distance_from_Home',hue='Learning_Disabilities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Distance_from_Home', ylabel='count'>

# %%
sns.countplot(x='Distance_from_Home',hue='Internet_Access',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Distance_from_Home', ylabel='count'>

# %%
sns.countplot(x='Distance_from_Home',hue='Extracurricular_Activities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Distance_from_Home', ylabel='count'>

# %%
sns.countplot(x='Distance_from_Home',hue='School_Type',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Distance_from_Home', ylabel='count'>

# %%
df['Distance_from_Home'].value_counts()
# Out:
# Distance_from_Home
# Near        3884
# Moderate    1998
# Far          658
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3814
# Female    2793
# Name: count, dtype: int64

# %%
df['Family_Income'].value_counts()
# Out:
# Family_Income
# Low       2672
# Medium    2666
# High      1269
# Name: count, dtype: int64

# %%
sns.countplot(x='Family_Income',hue='Gender',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Family_Income', ylabel='count'>

# %%
sns.countplot(x='Family_Income',hue='Learning_Disabilities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Family_Income', ylabel='count'>

# %%
sns.countplot(x='Family_Income',hue='Internet_Access',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Family_Income', ylabel='count'>

# %%
sns.countplot(x='Family_Income',hue='Extracurricular_Activities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Family_Income', ylabel='count'>

# %%
sns.countplot(x='Family_Income',hue='School_Type',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Family_Income', ylabel='count'>

# %%
df['Internet_Access'].value_counts()
# Out:
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64

# %%
df['Motivation_Level'].value_counts()
# Out:
# Motivation_Level
# Medium    3351
# Low       1937
# High      1319
# Name: count, dtype: int64

# %%
sns.countplot(x='Motivation_Level',hue='Gender',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='count'>

# %%
sns.countplot(x='Motivation_Level',hue='Learning_Disabilities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='count'>

# %%
sns.countplot(x='Motivation_Level',hue='Internet_Access',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='count'>

# %%
sns.countplot(x='Motivation_Level',hue='Extracurricular_Activities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='count'>

# %%
sns.countplot(x='Motivation_Level',hue='School_Type',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='count'>

# %%
df['Extracurricular_Activities'].value_counts()
# Out:
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64

# %%
df['Access_to_Resources'].value_counts()
# Out:
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64

# %%
sns.countplot(x='Access_to_Resources',hue='School_Type',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Access_to_Resources', ylabel='count'>

# %%
sns.countplot(x='Access_to_Resources',hue='Extracurricular_Activities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Access_to_Resources', ylabel='count'>

# %%
sns.countplot(x='Access_to_Resources',hue='Internet_Access',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Access_to_Resources', ylabel='count'>

# %%
sns.countplot(x='Access_to_Resources',hue='Gender',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Access_to_Resources', ylabel='count'>

# %%
sns.countplot(x='Access_to_Resources',hue='Learning_Disabilities',data = df) # Gender , Learning_Disabilities , Internet_Access , Extracurricular_Activities , School_Type
# Out:
# <Axes: xlabel='Access_to_Resources', ylabel='count'>

# %%
df['School_Type'].value_counts()
# Out:
# School_Type
# Public     4598
# Private    2009
# Name: count, dtype: int64

# %%
df[(df['Gender']=='Female') & (df['Internet_Access']=='No') & (df['Learning_Disabilities']=='No') & (df['Extracurricular_Activities']=='No') & (df['School_Type']=='Private')]['Exam_Score'].agg(['mean','min','max','std','var','count','sum'])
# Out:
# mean       66.393939
# min        58.000000
# max        73.000000
# std         3.408990
# var        11.621212
# count      33.000000
# sum      2191.000000
# Name: Exam_Score, dtype: float64

# %%
df.groupby(['Gender','Internet_Access','Learning_Disabilities','Extracurricular_Activities','School_Type'])['Exam_Score'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                                                                           mean  \
# Gender Internet_Access Learning_Disabilities Extracurricular_Activities School_Type
# Female No              No                    No                         Private      66.393939
#                                                                         Public       66.574074
#                                              Yes                        Private      66.914286
#                                                                         Public       66.962025
#                        Yes                   No                         Private      63.000000
#                                                                         Public       64.800000
#                                              Yes                        Private      63.166667
#                                                                         Public       65.800000
# ...

# %%
df[
    (df['Access_to_Resources']=='Medium') &  
    (df['Motivation_Level']=='Medium') & 
    (df['Family_Income']=='Medium') & 
    (df['Distance_from_Home']=='Near') & 
    (df['Parental_Education_Level']=='High School') & 
    (df['Peer_Influence']=='Positive')

]['Exam_Score'].agg(['mean','min','max','std','var','count','sum'])
# Out:
# mean       67.987500
# min        61.000000
# max        78.000000
# std         3.346995
# var        11.202373
# count      80.000000
# sum      5439.000000
# Name: Exam_Score, dtype: float64

# %%
df.groupby(['Access_to_Resources', 'Motivation_Level' , 'Family_Income' , 'Distance_from_Home' ,'Parental_Education_Level' ,'Peer_Influence'])['Exam_Score'].agg(['mean','min','max','std','var','count','sum'])
# Out:
#                                                                                                                     mean  \
# Access_to_Resources Motivation_Level Family_Income Distance_from_Home Parental_Education_Level Peer_Influence
# High                High             High          Far                College                  Neutral         65.000000
#                                                                       High School              Negative        75.000000
#                                                                                                Positive        69.500000
#                                                                       Postgraduate             Neutral         65.000000
#                                                    Moderate           College                  Negative        63.000000
# ...                                                                                                                  ...
# ...

# %%
df.pivot_table(index=['Parental_Education_Level','Family_Income','Internet_Access'],columns=['Gender','School_Type'],values='Exam_Score',aggfunc=['mean','median'])
# Out:
#                                                              mean             \
# Gender                                                     Female
# School_Type                                               Private     Public
# Parental_Education_Level Family_Income Internet_Access
# College                  High          No               67.250000  68.333333
#                                        Yes              68.904762  67.845455
#                          Low           No               66.266667  65.350000
#                                        Yes              67.477273  66.917051
#                          Medium        No               67.714286  66.782609
#                                        Yes              67.391304  67.517544
# High School              High          No               64.545455  67.470588
#                                        Yes              67.281250  67.657143
#                          Low           No               66.400000  64.964286
# ...

# %%
df.pivot_table(index=['Parental_Education_Level','Family_Income','Internet_Access'],columns=['Gender','School_Type'],values='Exam_Score',aggfunc=['max','min'])
# Out:
#                                                            max                 \
# Gender                                                  Female           Male
# School_Type                                            Private Public Private
# Parental_Education_Level Family_Income Internet_Access
# College                  High          No                   70     72      68
#                                        Yes                 100     77      76
#                          Low           No                   71     74      71
#                                        Yes                  76     94      88
#                          Medium        No                   74     75      71
#                                        Yes                  75     98      92
# High School              High          No                   70    101      82
#                                        Yes                  79     93      88
# ...

# %%
df.melt(id_vars=['Gender','Internet_Access'],value_vars=['Exam_Score','Sleep_Hours'],var_name='Categories',value_name='Final Output').iloc[100:]
# Out:
#        Gender Internet_Access   Categories  Final Output
# 100      Male             Yes   Exam_Score            67
# 101    Female             Yes   Exam_Score            65
# 102      Male             Yes   Exam_Score            65
# 103      Male             Yes   Exam_Score            69
# 104      Male             Yes   Exam_Score            63
# ...       ...             ...          ...           ...
# 13209  Female             Yes  Sleep_Hours             7
# 13210  Female             Yes  Sleep_Hours             8
# 13211  Female             Yes  Sleep_Hours             6
# 13212  Female             Yes  Sleep_Hours             6
# 13213    Male             Yes  Sleep_Hours             9
#
# [13114 rows x 4 columns]

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
sns.distplot(df['Exam_Score'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21984\4271735307.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Exam_Score'])
# <Axes: xlabel='Exam_Score', ylabel='Density'>

# %%
sns.boxplot(df['Exam_Score'])
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
sns.barplot(x='Parental_Education_Level',y='Exam_Score',hue='Gender' ,data = df)
# Out:
# <Axes: xlabel='Parental_Education_Level', ylabel='Exam_Score'>

# %%
sns.barplot(x='Family_Income',y='Exam_Score',hue='Gender' ,data = df)
# Out:
# <Axes: xlabel='Family_Income', ylabel='Exam_Score'>

# %%
sns.lmplot(x='Sleep_Hours',y='Exam_Score',hue='Gender',data = df)
